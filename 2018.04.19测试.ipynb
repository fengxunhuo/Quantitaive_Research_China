# %%
import warnings
warnings.filterwarnings('ignore')

from jaqs_fxdayu.data import DataView
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910",
"remote.data.username": "15151809905",
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4"
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
dv = DataView()
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success

# %%
props = {'start_date': 20160501, 'end_date': 20160531, 'symbol':'601360.SH',
         'fields':"open,close,volume,turnover",
         'freq': 1}
dv.init_from_config(props, ds)
dv.prepare_data()

#data1=dv.get('601360.SH',fields="open,close,volume,turnover")
#a=dv.add_formula("vibration", "(close-open)/open", is_quarterly=False)
#b=a
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'trade_date,low,vwap_adj,trade_status,volume,high_adj,open_adj,turnover,close_adj,vwap,symbol,low_adj,close,open,high'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'open,vwap,close,low,high,symbol,trade_date'}
# WARNING: some data is unavailable:
#     At fields
# Query data - daily fields prepared.
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a6a1d9e354ee> in <module>()
#       3          'freq': 1}
#       4 dv.init_from_config(props, ds)
# ----> 5 dv.prepare_data()
#       6
#       7 #data1=dv.get('601360.SH',fields="open,close,volume,turnover")
#
# ...

# %%
props = {'start_date': 20170501, 'end_date': 20170531, 'symbol':'600153.SH',
         'fields':"open,close,volume,turnover",
         'freq': 1}
dv.init_from_config(props, ds)
dv.prepare_data()

data1=dv.get('600153.SH',fields="open,close,volume,turnover")
vibration=dv.add_formula("vibration", "(close-open)/open", is_quarterly=False)
b=b.add(vibration, fill_value=0)
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'turnover,close,open,vwap,open_adj,trade_date,symbol,low_adj,low,volume,high,high_adj,vwap_adj,close_adj,trade_status'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'close,open,vwap,low,high,symbol,trade_date'}
# Query data - daily fields prepared.
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
props = {'start_date': 20170501, 'end_date': 20170531, 'symbol':'300236.SZ',
         'fields':"open,close,volume,turnover",
         'freq': 1}
dv.init_from_config(props, ds)
dv.prepare_data()

data1=dv.get('300236.SZ',fields="open,close,volume,turnover")
vibration=dv.add_formula("vibration", "(close-open)/open", is_quarterly=False)
b=b.add(vibration, fill_value=0)
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'turnover,close,open,vwap,open_adj,trade_date,symbol,low_adj,low,volume,high,high_adj,vwap_adj,close_adj,trade_status'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'close,open,vwap,low,high,symbol,trade_date'}
# Query data - daily fields prepared.
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
props = {'start_date': 20170501, 'end_date': 20170531, 'symbol':'600300.SH',
         'fields':"open,close,volume,turnover",
         'freq': 1}
dv.init_from_config(props, ds)
dv.prepare_data()

data1=dv.get('600300.SH',fields="open,close,volume,turnover")
vibration=dv.add_formula("vibration", "(close-open)/open", is_quarterly=False)
b=b.add(vibration, fill_value=0)
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'turnover,close,open,vwap,open_adj,trade_date,symbol,low_adj,low,volume,high,high_adj,vwap_adj,close_adj,trade_status'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'close,open,vwap,low,high,symbol,trade_date'}
# Query data - daily fields prepared.
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
b
# Out:
# symbol      300236.SZ  600153.SH  600300.SH
# trade_date
# 20170502     0.001689  -0.015820  -0.010638
# 20170503    -0.006764   0.008475   0.014260
# 20170504     0.003405  -0.017692  -0.003559
# 20170505    -0.018424   0.010363  -0.053476
# 20170508     0.017764   0.010300  -0.062385
# 20170509     0.019322  -0.003442   0.041746
# 20170510    -0.019894  -0.023276  -0.067290
# 20170511     0.054110   0.009709   0.015414
# 20170512    -0.017097   0.006167  -0.011494
# 20170515    -0.024207   0.001744  -0.011538
# 20170516     0.055987   0.018389   0.000000
# 20170517     0.011855   0.000000   0.061657
# 20170518    -0.015969   0.007819  -0.041509
# 20170519     0.026494  -0.001730  -0.007707
# 20170522    -0.041280  -0.012965  -0.034884
# 20170523    -0.057391   0.013239  -0.106299
# 20170524     0.030786   0.008780   0.025105
# 20170525    -0.009563   0.021853   0.033195
# 20170526     0.002778  -0.000855  -0.012245
# 20170531    -0.035908  -0.020305  -0.028455
