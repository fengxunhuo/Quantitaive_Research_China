# %% [markdown]
# · 2017年与上证指数比较

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
import datetime
# %matplotlib inline

# %%
def change1(data, df, N):
    for i in range(len(data.index.values)):
        L = (df['close'].values[i+N-1]-df['close'].values[i])/df['close'].values[i]/N
        change_N2.append(L)
    return change_N2

# %%
data = pd.read_csv('D:/Documents/Go Abroad/实习/成交金额/Python数据/2017_4/2017-5-20change.csv',encoding='gbk',engine='python')

# %%
avg_change = data['avg_change2']

# %%
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910", # 数据服务tcp地址
"remote.data.username": "15151809905",# 账号
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4",
"timeout":180 #超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
dt = datetime.datetime.strptime(data['date'].values[0], "%Y-%m-%d")
dtf = dt + datetime.timedelta(days=-3)
T = dtf.strftime("%Y-%m-%d")

# %%
df,msg = ds.daily("000001.SH",start_date= T,end_date=20171231, fields = 'trade_date, code, close', adjust_mode="post")

# %%
df = df[['trade_date', 'code', 'close']]
change = df['close'].pct_change()
df['change'] = change
df = df.iloc[1:,:]
df = df.reset_index(drop = True)

# %%
change_N2 = []
change_N2 = change1(data, df, 5)

df2 = df.iloc[1:len(data.index.values)+1,:]
df2['change_N2'] = change_N2

data.index = data['date'].tolist()
df2.index = data['date'].tolist()
# Out:
# D:\Anaconda3\envs\dayu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.figure(figsize=(15, 7))
data['avg_change2'].plot()
df2['change_N2'].plot()
plt.legend()
plt.title("Comparation with SCI")
plt.xlabel("Date")
plt.ylabel("Avg_change")
# Out:
# Text(0,0.5,'Avg_change')

# %%
divi = data['avg_change2'] - df2['change_N2']
plt.figure(figsize=(15, 7))
divi.plot()

# %%
np.mean(divi)
# Out:
# -0.0005750812807786362

# %% [markdown]
# ·2016年与上证指数比较

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
import datetime
# %matplotlib inline

# %%
def change1(data, df, N):
    for i in range(len(data.index.values)):
        L = (df['close'].values[i+N-1]-df['close'].values[i])/df['close'].values[i]/N
        change_N2.append(L)
    return change_N2

# %%
data = pd.read_csv('D:/Documents/Go Abroad/实习/成交金额/Python数据/2016_4/2016-5-20change.csv',encoding='gbk',engine='python')

# %%
avg_change = data['avg_change2']

# %%
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910", # 数据服务tcp地址
"remote.data.username": "15151809905",# 账号
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4",
"timeout":180 #超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
dt = datetime.datetime.strptime(data['date'].values[0], "%Y-%m-%d")
dtf = dt + datetime.timedelta(days=-1)
T = dtf.strftime("%Y-%m-%d")

# %%
df,msg = ds.daily("000001.SH",start_date= T,end_date=20161231, fields = 'trade_date, code, close', adjust_mode="post")

# %%
df = df[['trade_date', 'code', 'close']]
change = df['close'].pct_change()
df['change'] = change
df = df.iloc[1:,:]
df = df.reset_index(drop = True)

# %%
change_N2 = []
change_N2 = change1(data, df, 5)

df2 = df.iloc[1:len(data.index.values)+1,:]
df2['change_N2'] = change_N2

data.index = data['date'].tolist()
df2.index = data['date'].tolist()
# Out:
# D:\Anaconda3\envs\dayu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.figure(figsize=(15, 7))
data['avg_change2'].plot()
df2['change_N2'].plot()
plt.legend()
plt.title("Comparation with SCI")
plt.xlabel("Date")
plt.ylabel("Avg_change")
# Out:
# Text(0,0.5,'Avg_change')

# %%
divi = data['avg_change2'] - df2['change_N2']
plt.figure(figsize=(15, 7))
divi.plot()

# %%
np.mean(divi)
# Out:
# 0.0013196620395603661

# %% [markdown]
# · 2015年与上证指数比较

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
import datetime
# %matplotlib inline

# %%
def change1(data, df, N):
    for i in range(len(data.index.values)):
        L = (df['close'].values[i+N-1]-df['close'].values[i])/df['close'].values[i]/N
        change_N2.append(L)
    return change_N2

# %%
data = pd.read_csv('D:/Documents/Go Abroad/实习/成交金额/Python数据/2015_4/2015-5-20change.csv',encoding='gbk',engine='python')
avg_change = data['avg_change2']

# %%
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910", # 数据服务tcp地址
"remote.data.username": "15151809905",# 账号
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4",
"timeout":180 #超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
dt = datetime.datetime.strptime(data['date'].values[0], "%Y-%m-%d")
dtf = dt + datetime.timedelta(days=-1)
T = dtf.strftime("%Y-%m-%d")

# %%
df,msg = ds.daily("000001.SH",start_date= T,end_date=20151231, fields = 'trade_date, code, close', adjust_mode="post")

# %%
df = df[['trade_date', 'code', 'close']]
change = df['close'].pct_change()
df['change'] = change
df = df.iloc[1:,:]
df = df.reset_index(drop = True)

# %%
change_N2 = []
change_N2 = change1(data, df, 5)

df2 = df.iloc[1:len(data.index.values)+1,:]
df2['change_N2'] = change_N2

data.index = data['date'].tolist()
df2.index = data['date'].tolist()
# Out:
# D:\Anaconda3\envs\dayu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.figure(figsize=(15, 7))
data['avg_change2'].plot()
df2['change_N2'].plot()
plt.legend()
plt.title("Comparation with SCI")
plt.xlabel("Date")
plt.ylabel("Avg_change")
# Out:
# Text(0,0.5,'Avg_change')

# %%
divi = data['avg_change2'] - df2['change_N2']
plt.figure(figsize=(15, 7))
divi.plot()

# %%
np.mean(divi)
# Out:
# 0.004404897703622391

# %% [markdown]
# · 2014年与上证指数比较

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
import datetime
# %matplotlib inline

# %%
def change1(data, df, N):
    for i in range(len(data.index.values)):
        L = (df['close'].values[i+N-1]-df['close'].values[i])/df['close'].values[i]/N
        change_N2.append(L)
    return change_N2

# %%
data = pd.read_csv('D:/Documents/Go Abroad/实习/成交金额/Python数据/2014_4/2014-5-20change.csv',encoding='gbk',engine='python')
avg_change = data['avg_change2']

# %%
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910", # 数据服务tcp地址
"remote.data.username": "15151809905",# 账号
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4",
"timeout":180 #超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
dt = datetime.datetime.strptime(data['date'].values[0], "%Y-%m-%d")
dtf = dt + datetime.timedelta(days=-1)
T = dtf.strftime("%Y-%m-%d")

# %%
df,msg = ds.daily("000001.SH",start_date= T,end_date=20141231, fields = 'trade_date, code, close', adjust_mode="post")

# %%
df = df[['trade_date', 'code', 'close']]
change = df['close'].pct_change()
df['change'] = change
df = df.iloc[1:,:]
df = df.reset_index(drop = True)

# %%
change_N2 = []
change_N2 = change1(data, df, 5)

df2 = df.iloc[1:len(data.index.values)+1,:]
df2['change_N2'] = change_N2

data.index = data['date'].tolist()
df2.index = data['date'].tolist()
# Out:
# D:\Anaconda3\envs\dayu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.figure(figsize=(15, 7))
data['avg_change2'].plot()
df2['change_N2'].plot()
plt.legend()
plt.title("Comparation with SCI")
plt.xlabel("Date")
plt.ylabel("Avg_change")
# Out:
# Text(0,0.5,'Avg_change')

# %%
divi = data['avg_change2'] - df2['change_N2']
plt.figure(figsize=(15, 7))
divi.plot()

# %%
np.mean(divi)
# Out:
# -0.00025754723519782953

# %% [markdown]
# · 2013年与上证指数比较

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
import datetime
# %matplotlib inline

# %%
def change1(data, df, N):
    for i in range(len(data.index.values)):
        L = (df['close'].values[i+N-1]-df['close'].values[i])/df['close'].values[i]/N
        change_N2.append(L)
    return change_N2

# %%
data = pd.read_csv('D:/Documents/Go Abroad/实习/成交金额/Python数据/2013_4/2013-5-20change.csv',encoding='gbk',engine='python')
avg_change = data['avg_change2']

# %%
from jaqs_fxdayu.data import RemoteDataService # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
"remote.data.address": "tcp://data.tushare.org:8910", # 数据服务tcp地址
"remote.data.username": "15151809905",# 账号
"remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjEwNDIyMTI0NzkiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTUxNTE4MDk5MDUifQ.-k9cf1VxKPAyf2NrhYkYrQbwW6N_bEn09PCd7AteOE4",
"timeout":180 #超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 15151809905@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
dt = datetime.datetime.strptime(data['date'].values[0], "%Y-%m-%d")
dtf = dt + datetime.timedelta(days=-1)
T = dtf.strftime("%Y-%m-%d")

# %%
df,msg = ds.daily("000001.SH",start_date= T,end_date=20131231, fields = 'trade_date, code, close', adjust_mode="post")

# %%
df = df[['trade_date', 'code', 'close']]
change = df['close'].pct_change()
df['change'] = change
df = df.iloc[1:,:]
df = df.reset_index(drop = True)

# %%
change_N2 = []
change_N2 = change1(data, df, 5)

df2 = df.iloc[1:len(data.index.values)+1,:]
df2['change_N2'] = change_N2

data.index = data['date'].tolist()
df2.index = data['date'].tolist()
# Out:
# D:\Anaconda3\envs\dayu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.figure(figsize=(15, 7))
data['avg_change2'].plot()
df2['change_N2'].plot()
plt.legend()
plt.title("Comparation with SCI")
plt.xlabel("Date")
plt.ylabel("Avg_change")
# Out:
# Text(0,0.5,'Avg_change')

# %%
divi = data['avg_change2'] - df2['change_N2']
plt.figure(figsize=(15, 7))
divi.plot()

# %%
np.mean(divi)
# Out:
# -0.000443799018962952

# %%
N1 = 3
N2 = 5
#K = 200
D = 100
#Z = 30
T = '2017-01-09'
stock_bestinf = best_perf(data, stock_eg, T, N1, N2, D)

# %%
stock_bestinf
# Out:
#          stock        date   close        value  change_N1  change_N2  \
# 596619  300577  2017-01-09   76.06   1267920.20   0.068652  -0.000658
# 406755  603298  2017-01-09   25.83   2238427.80  -0.004118  -0.023503
# 389442  603218  2017-01-09   43.27   1774070.00  -0.013895  -0.016807
# 424121  603577  2017-01-09   36.22   1056899.60   0.097410  -0.038320
# 597502  300581  2017-01-09  106.30   1201190.00   0.110368  -0.018117
# 445791  603416  2017-01-09   49.89   1252239.00  -0.029406  -0.020745
# 351145  601188  2017-01-09    6.49   8540051.93   0.079829  -0.031563
